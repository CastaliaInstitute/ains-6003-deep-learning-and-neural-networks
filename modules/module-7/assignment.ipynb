# %% [markdown]
# # Module 7 Assignment
#
# ## Module 7 Assignment
#
# ## Prompt
#
# Apply concepts from Module 7 (Generative models and applications). Submit a 600–900 word technical memo with code snippets or diagrams as needed.
#
# ## Deliverable
#
# Submit your memo and any notebook outputs via the course LMS.

# %%
# Draft notes
notes = ""
notes
