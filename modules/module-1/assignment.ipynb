# %% [markdown]
# # Module 1 Assignment
#
# ## Designing a baseline MLP
#
# ## Prompt
#
# Specify an MLP for a tabular or vector classification task: input dimension, hidden layers, activation, and output head. Justify each choice in 600-900 words.
#
# ## Deliverable
#
# Submit your memo and any notebook outputs via the course LMS.

# %%
# Draft notes
notes = ""
notes
