# %% [markdown]
# # Module 2 Assignment
#
# ## Tracing gradients through a graph
#
# ## Prompt
#
# Draw or describe the computational graph for a two-layer network with MSE loss. Identify which intermediate values backprop must store. Submit 600-900 words plus a diagram.
#
# ## Deliverable
#
# Submit your memo and any notebook outputs via the course LMS.

# %%
# Draft notes
notes = ""
notes
