# %% [markdown]
# # Module 6 Lab: Attention patterns
#
# Visualize attention weights from a small transformer block on sample inputs.

# %%
# Scaffold: import core libraries
import math
print("Module 6 lab ready")
