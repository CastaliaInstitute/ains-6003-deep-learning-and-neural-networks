# %% [markdown]
# # Module 7 Lab: Generative vs discriminative
#
# Contrast a classifier head with a simple generative baseline on the same dataset.

# %%
# Scaffold: import core libraries
import math
print("Module 7 lab ready")
