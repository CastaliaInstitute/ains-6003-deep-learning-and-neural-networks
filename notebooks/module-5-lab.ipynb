# %% [markdown]
# # Module 5 Lab: Sequence prediction
#
# Train a small recurrent model on a character- or token-level sequence task.

# %%
# Scaffold: import core libraries
import math
print("Module 5 lab ready")
