# %% [markdown]
# # Module 4 Lab: CNN feature maps
#
# Inspect convolutional filters and activation maps on a small image dataset.

# %%
# Scaffold: import core libraries
import math
print("Module 4 lab ready")
