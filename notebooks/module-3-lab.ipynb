# %% [markdown]
# # Module 3 Lab: SGD vs Adam on a synthetic surface
#
# Compare stochastic gradient descent and Adam on a simple regression task; plot loss curves.

# %%
# Scaffold: import core libraries
import math
print("Module 3 lab ready")
