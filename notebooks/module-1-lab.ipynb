# %% [markdown]
# # Module 1 Lab: Forward pass and activations
#
# Implement a tiny MLP forward pass in NumPy or PyTorch; compare ReLU vs sigmoid on a toy dataset.

# %%
import math
print("Module 1 lab")
