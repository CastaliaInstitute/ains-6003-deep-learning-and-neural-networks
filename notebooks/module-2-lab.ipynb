# %% [markdown]
# # Module 2 Lab: Manual vs autograd gradients
#
# Verify a hand-derived gradient for a scalar loss against `torch.autograd` on a tiny network.

# %%
import math
print("Module 2 lab")
